# %%
from IPython.display import display


from plotter_components import *
# %matplotlib notebook
# Out:
# /opt/conda_envs/analysis-2016-09-30/lib/python3.5/site-packages/tifffile/tifffile.py:271: UserWarning: failed to import the optional _tifffile C extension module.
# Loading of some compressed images will be very slow.
# Tifffile.c can be obtained at http://www.lfd.uci.edu/~gohlke/
#   "failed to import the optional _tifffile C extension module.\n"

# %%
display(widgets.HBox([DB_search_widget, refresh_headers_widget]))
display(select_scan_id_widget)

# %%
plt.figure()
display(widgets.HBox([select_x_widget, select_y_widget, use_mon_widget, select_mon_widget]))
display(widgets.HBox([plot_button, clear_button]) )
# Out:
# <img src="data:image/png;base64,...">

# %%
display(starting_values_display)

# %%
display(filename_widget, save_button)

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to show/hide code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to show/hide code."></form>
